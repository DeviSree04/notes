# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.shopsy.in/books-online"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
asmt=BeautifulSoup(response.text)

# %%
asmt
# Out:
# <!DOCTYPE html>
# ...

# %%
name=asmt.select(".r-7o8qx1")

# %%
name
# Out:
# [<div class="css-1dbjc4n r-op4f77 r-13awgt0 r-1et8rh5 r-1enofrn r-1cwl3u0 r-7o8qx1"><div class="_1PnKMA" style="max-height:16px;line-height:16px"><div><div class="css-901oao" dir="auto"><span class="css-901oao css-16my406 r-op4f77 r-13awgt0 r-1et8rh5 r-1enofrn r-1cwl3u0 r-7o8qx1" dir="auto">Best Book On SSB Interview, Paperback, Commander RS Rathore (Retd.)</span></div></div></div></div>,
#  <span class="css-901oao css-16my406 r-op4f77 r-13awgt0 r-1et8rh5 r-1enofrn r-1cwl3u0 r-7o8qx1" dir="auto">Best Book On SSB Interview, Paperback, Commander RS Rathore (Retd.)</span>,
# ...

# %%
review=asmt.select(".r-1vzi8xi")

# %%
review
# Out:
# [<div class="css-901oao css-bfa6kz r-1kihuf0 r-1h7g6bg r-1et8rh5 r-1enofrn r-1f6r7vd r-l4nmg1 r-1vzi8xi" dir="auto">(638)</div>,
#  <div class="css-901oao r-1kihuf0 r-1w427b9 r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi" dir="auto">8% off</div>,
#  <div class="css-901oao r-1kihuf0 r-1h7g6bg r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi r-142tt33" dir="auto">525</div>,
#  <div class="css-901oao r-1kihuf0 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t r-q4m81j r-1vzi8xi" dir="auto">₹480</div>,
#  <div class="css-901oao css-bfa6kz r-1kihuf0 r-1h7g6bg r-1et8rh5 r-1enofrn r-1f6r7vd r-l4nmg1 r-1vzi8xi" dir="auto">(164)</div>,
#  <div class="css-901oao r-1kihuf0 r-1w427b9 r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi" dir="auto">75% off</div>,
#  <div class="css-901oao r-1kihuf0 r-1h7g6bg r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi r-142tt33" dir="auto">1,000</div>,
# ...

# %%
price=asmt.select(".r-1vzi8xi")

# %%
price
# Out:
# [<div class="css-901oao css-bfa6kz r-1kihuf0 r-1h7g6bg r-1et8rh5 r-1enofrn r-1f6r7vd r-l4nmg1 r-1vzi8xi" dir="auto">(638)</div>,
#  <div class="css-901oao r-1kihuf0 r-1w427b9 r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi" dir="auto">8% off</div>,
#  <div class="css-901oao r-1kihuf0 r-1h7g6bg r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi r-142tt33" dir="auto">525</div>,
#  <div class="css-901oao r-1kihuf0 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t r-q4m81j r-1vzi8xi" dir="auto">₹480</div>,
#  <div class="css-901oao css-bfa6kz r-1kihuf0 r-1h7g6bg r-1et8rh5 r-1enofrn r-1f6r7vd r-l4nmg1 r-1vzi8xi" dir="auto">(164)</div>,
#  <div class="css-901oao r-1kihuf0 r-1w427b9 r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi" dir="auto">75% off</div>,
#  <div class="css-901oao r-1kihuf0 r-1h7g6bg r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw r-q4m81j r-1vzi8xi r-142tt33" dir="auto">1,000</div>,
# ...

# %%
import pandas

# %%
booklist=pandas.DataFrame(price,columns=['Price'])

# %%
booklist
# Out:
#       Price
# 0     (638)
# 1    8% off
# 2       525
# 3      ₹480
# 4     (164)
# 5   75% off
# 6     1,000
# 7      ₹250
# 8   (4,638)
# 9   93% off
# 10      977
# 11      ₹64
# 12  40% off
# 13      395
# 14     ₹235

# %%
booklist["review"]=review

# %%
booklist["name"]=review

# %%
booklist
# Out:
#       Price     review       name
# 0     (638)    [(638)]    [(638)]
# 1    8% off   [8% off]   [8% off]
# 2       525      [525]      [525]
# 3      ₹480     [₹480]     [₹480]
# 4     (164)    [(164)]    [(164)]
# 5   75% off  [75% off]  [75% off]
# 6     1,000    [1,000]    [1,000]
# 7      ₹250     [₹250]     [₹250]
# 8   (4,638)  [(4,638)]  [(4,638)]
# 9   93% off  [93% off]  [93% off]
# 10      977      [977]      [977]
# 11      ₹64      [₹64]      [₹64]
# 12  40% off  [40% off]  [40% off]
# 13      395      [395]      [395]
# 14     ₹235     [₹235]     [₹235]

# %%
booklist.to_csv("C:\\Users\\aedpu\\OneDrive\\documents\\books.csv")
